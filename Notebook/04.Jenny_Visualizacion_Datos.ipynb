# %% [markdown]
# # Visualizacion de Datos

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Diahramas de Dispersion (Scatterplot)

x = np.arange(2, 20)
y = x**2
y = x**3


plt.scatter(x, y, color="green", marker="*", label="Data")

plt.title("Funciones x ", fontsize=20, color="pink" )
plt.xlabel("x")
plt.ylabel("y")
plt.grid()
plt.legend()

# %%
# Diahramas de Dispersion (Scatterplot)

x = np.arange(2, 20)
y = x**2
y2 = x**3

plt.scatter(x, y, color="blue", marker="*", label="x^2")
plt.scatter(x, y2, color="green", marker="s", label="x^3")
plt.plot(x, y2, color="pink", label="line")

plt.title("Funciones polinomicas", fontsize=20, color="red" )
plt.xlabel("x")
plt.ylabel("y")
plt.grid()
plt.legend()

plt.text(10, 7000, "texto", color="Blue")
# Out:
# Text(10, 7000, 'texto')

# %%
# Histogramas

mean= 5
std = 3
n = 10000
x = np.random.normal(mean, std, n)
x

plt.hist(x, bins=20);

plt.title("Histograma de una variable aleatorias", fontsize=20, color="red" )
plt.xlabel("x")
plt.ylabel("frecuencia")
plt.grid()
plt.legend()

plt.text(6, 1400, f"Mean: {mean} +/- {std}", color="Blue")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Text(6, 1400, 'Mean: 5 +/- 3')

# %%
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x17c4da9a8b0>,
#   <matplotlib.lines.Line2D at 0x17c4da9ab80>],
#  'caps': [<matplotlib.lines.Line2D at 0x17c4da9ae50>,
#   <matplotlib.lines.Line2D at 0x17c4daa8160>],
#  'boxes': [<matplotlib.lines.Line2D at 0x17c4da9a5b0>],
#  'medians': [<matplotlib.lines.Line2D at 0x17c4daa8430>],
#  'fliers': [<matplotlib.lines.Line2D at 0x17c4daa8700>],
#  'means': []}

# %%
plt.boxplot(x, vert=False);

# %%
# Subplots

fig, ax = plt.subplots(ncols=2, nrows=1, figsize=(15, 5))
ax[0].hist(x);
ax[1].boxplot(x, vert=False);

# %%
# Subplots

fig, ax = plt.subplots(ncols=1, nrows=2, figsize=(5, 10), sharex=True)
ax[0].hist(x);
ax[1].boxplot(x, vert=False);

# %%
# Barplot

classes = ["gastos", "perros", "ratones"]
totales = [20, 35, 15]

plt.barh(classes, totales)
# Out:
# <BarContainer object of 3 artists>
